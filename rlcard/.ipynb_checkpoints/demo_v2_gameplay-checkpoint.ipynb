# %%
# ! conda install pytorch torchvision torchaudio cpuonly -c pytorch

# %% [markdown]
# # Import

# %%
import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger

# %% [markdown]
# # Training

# %%
#### import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger


# Check whether gpu is available
device = get_device()

# Seed numpy, torch, random
set_seed(7)

# Make the environment with seed
env = rlcard.make("bridge", config={'seed': 7})

# Initialize the agent and use random agents as opponents
from rlcard.agents import DQNAgent
agent1 = DQNAgent(num_actions=env.num_actions,
                 state_shape=env.state_shape[0],
                 mlp_layers=[700 , 700],
                 device=device,
                 name='Player 1')

agent2 = RandomAgent(num_actions=env.num_actions, name='Player 2')

agent3 = DQNAgent(num_actions=env.num_actions,
                  state_shape=env.state_shape[0],
                  mlp_layers=[700 , 700],
                  device=device,
                  name='Player 3',
                 )

agent4 = RandomAgent(num_actions=env.num_actions, name='Player 4')


'''
agents = [agent]
for _ in range(env.num_players):
    agents.append(RandomAgent(num_actions=env.num_actions))
'''

agents = [agent1, agent2, agent3, agent4]

env.set_agents(agents)

#for episode in range(10):
for episode in range(2000):
    #print('\n episode:', episode)
    trajectories, payoffs = env.run(is_training=True)
    #break
    # Training
    trajectories = reorganize(trajectories, payoffs)
    for ts in trajectories[0]:
        agent1.feed(ts)
        #agent.feed(ts)
        #rl_loss = agent.train_rl()
        #sl_loss = agent.train_sl()
    for ts in trajectories[2]:
        agent3.feed(ts)
# Out:
# --> Running on the CPU
# C:\Users\ha.agarwal\Downloads\tarneeb_enviornment-main\tarneeb_clone_v01\rlcard\rlcard\agents\dqn_agent.py:216: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   state_batch, action_batch, reward_batch, next_state_batch, legal_actions_batch, done_batch = self.memory.sample()
# INFO - Step 100, rl-loss: 0.47509312629699707
# INFO - Copied model parameters to target network.
# INFO - Step 100, rl-loss: 16.814662933349619
# INFO - Copied model parameters to target network.
# INFO - Step 148, rl-loss: 16.6873779296875225

# %% [markdown]
# # Testing

# %%
# Simulation

def run_1_simulation():
    trajectories, payoffs = env.run()
    if payoffs[0] > payoffs[1]:
        return 0
    else:
        return 1

# %%
l = [run_1_simulation() for i in range(2000)] 

sum(l) / len(l)
# Out:
# 0.233

# %%
1 - sum(l) / len(l)
# Out:
# 0.767

# %% [markdown]
# # Game Play

# %% [markdown]
# Play Game for 1 fateiyah

# %%
agent1.verbose = True
agent2.verbose = True
agent3.verbose = True

# %%
##### import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger
from rlcard.agents.human_agent_bridge import HumanAgentBridge

env2 = rlcard.make("bridge", config={'seed': 7, 'verbose': True})

agents = [
          agent1,
          agent2,
          agent3,
          #RandomAgent(num_actions=env2.num_actions, name='Player 1', verbose=True),
          #RandomAgent(num_actions=env2.num_actions, name='Player 2', verbose=True),
          #RandomAgent(num_actions=env2.num_actions, name='Player 3', verbose=True),
          HumanAgentBridge(num_actions=env2.num_actions, name='Player 4', verbose=True)
         ]

env2.set_agents(agents)

_, payoffs = env2.run()
# Out:
# **************************************** Setup ****************************************
# Dealer ID: 1
#
# Player1: [3H, 5D, 4D, TC, JS, QS, 3S, 6H, 8D, 7C, 4C, QD, TH]
#
# Player2: [5S, 9H, KS, KC, 5H, KD, 9C, KH, 8C, 2S, 5C, 2D, 4S]
#
# Player3: [3D, AD, TD, JH, 8S, AC, AS, TS, 9S, 6S, 7H, 7D, QH]
#
# Player4: [2H, JD, 6C, 2C, 8H, 4H, QC, JC, 6D, 9D, AH, 7S, 3C]
#
# Seating Order:
#     p1
# p2      p4
#     p3
#
# **************************************** Game Start ****************************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '7_Club', '7_Diamond', '7_Hearts', '7_Spade', '8_Club', '8_Diamond', '8_Hearts', '8_Spade', '9_Club', '9_Diamond', '9_Hearts', '9_Spade', '10_Club', '10_Diamond', '10_Hearts', '10_Spade', '11_Club', '11_Diamond', '11_Hearts', '11_Spade', '12_Club', '12_Diamond', '12_Hearts', '12_Spade', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
#
# Final Choice: 12_Hearts
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_12_Hearts']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# Final Choice: Pass
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_12_Hearts', 'Player3_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# >> You choose action (integer): 0
#
# Final Choice: Pass
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_12_Hearts', 'Player3_Pass', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# Final Choice: 13_Diamond
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player1_13_Diamond', 'Player3_Pass', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass']
#
# Final Choice: Pass
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player1_13_Diamond', 'Player2_Pass', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass']
# Final Choice: Pass
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player1_13_Diamond', 'Player2_Pass', 'Player3_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass']
# >> You choose action (integer): 0
#
# Final Choice: Pass
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3H, 5D, 4D, TC, JS, QS, 3S, 6H, 8D, 7C, 4C, QD, TH]
# Final Choice: JS
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:                  ['JS']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5S, KS, 2S, 4S]
#
# Final Choice: KS
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:                  ['JS', 'KS']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8S, AS, TS, 9S, 6S]
# Final Choice: AS
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:                  ['JS', 'KS', 'AS']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [7S]
# >> You choose action (integer): 0
#
# Final Choice: 7S
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:                  ['JS', 'KS', 'AS', '7S']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3D, AD, TD, JH, 8S, AC, TS, 9S, 6S, 7H, 7D, QH]
# Final Choice: 7H
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH']
# 2. Pile Rep:                  ['7H']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [2H, 8H, 4H, AH]
# >> You choose action (integer): 0
#
# Final Choice: 2H
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'QS']
# 2. Pile Rep:                  ['7H', '2H']
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '4H', '5H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3H, 6H, TH]
# Final Choice: TH
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S']
# 2. Pile Rep:                  ['TH', '7H', '2H']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '3H', '4H', '6H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [9H, 5H, KH]
#
# Final Choice: KH
#
#  ************************************** ROUND END (Winner: Player 2)***********************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', '2S', '4S', '5S']
# 2. Pile Rep:                  ['TH', 'KH', '7H', '2H']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '3H', '4H', '6H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5S, 9H, KC, 5H, KD, 9C, 8C, 2S, 5C, 2D, 4S]
#
# Final Choice: 5H
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', 'JH', 'QH', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:                  ['5H']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '3H', '4H', '6H', '8H', '9H', 'AH', '2S', '3S', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [JH, QH]
# Final Choice: QH
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', '8H', 'AH']
# 2. Pile Rep:                  ['5H', 'QH']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '6H', '9H', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8H, 4H, AH]
# >> You choose action (integer): 0
#
# Final Choice: 8H
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', '3S', 'QS']
# 2. Pile Rep:                  ['5H', 'QH', '8H']
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '4H', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3H, 6H]
# Final Choice: 6H
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', 'JH', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:                  ['6H', '5H', 'QH', '8H']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '3H', '4H', '9H', 'AH', '2S', '3S', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3D, AD, TD, JH, 8S, AC, TS, 9S, 6S, 7D]
# Final Choice: 3D
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', 'AH']
# 2. Pile Rep:                  ['3D']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '9H', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [JD, 6D, 9D]
# >> You choose action (integer): 0
#
# Final Choice: JD
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '3S', 'QS']
# 2. Pile Rep:                  ['3D', 'JD']
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '6D', '7D', '9D', 'TD', 'KD', 'AD', '4H', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5D, 4D, 8D, QD]
# Final Choice: 5D
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '9H', '2S', '4S', '5S']
# 2. Pile Rep:                  ['5D', '3D', 'JD']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '4D', '6D', '7D', '8D', '9D', 'TD', 'QD', 'AD', '3H', '4H', 'JH', 'AH', '3S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [KD, 2D]
#
# Final Choice: KD
#
#  ************************************** ROUND END (Winner: Player 2)***********************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', '9H', '2S', '4S', '5S']
# 2. Pile Rep:                  ['5D', 'KD', '3D', 'JD']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '4D', '6D', '7D', '8D', '9D', 'TD', 'QD', 'AD', '3H', '4H', 'JH', 'AH', '3S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5S, 9H, KC, 9C, 8C, 2S, 5C, 2D, 4S]
#
# Final Choice: KC
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '7D', 'TD', 'AD', 'JH', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:                  ['KC']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', '2D', '4D', '6D', '8D', '9D', 'QD', '3H', '4H', '9H', 'AH', '2S', '3S', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [AC]
# Final Choice: AC
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', '4H', 'AH']
# 2. Pile Rep:                  ['KC', 'AC']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', '2D', '4D', '7D', '8D', 'TD', 'QD', 'AD', '3H', '9H', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [6C, 2C, QC, JC, 3C]
# >> You choose action (integer): 0
#
# Final Choice: 6C
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '8D', 'QD', '3H', '3S', 'QS']
# 2. Pile Rep:                  ['KC', 'AC', '6C']
# 3. Other Player Rep:          ['2C', '3C', '5C', '8C', '9C', 'JC', 'QC', '2D', '6D', '7D', '9D', 'TD', 'AD', '4H', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [TC, 7C, 4C]
# Final Choice: 7C
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['7D', 'TD', 'AD', 'JH', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:                  ['7C', 'KC', 'AC', '6C']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '8C', '9C', 'TC', 'JC', 'QC', '2D', '4D', '6D', '8D', '9D', 'QD', '3H', '4H', '9H', 'AH', '2S', '3S', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [AD, TD, JH, 8S, TS, 9S, 6S, 7D]
# Final Choice: TD
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', 'JC', 'QC', '6D', '9D', '4H', 'AH']
# 2. Pile Rep:                  ['TD']
# 3. Other Player Rep:          ['4C', '5C', '8C', '9C', 'TC', '2D', '4D', '7D', '8D', 'QD', 'AD', '3H', '9H', 'JH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [6D, 9D]
# >> You choose action (integer): 0
#
# Final Choice: 6D
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', 'TC', '4D', '8D', 'QD', '3H', '3S', 'QS']
# 2. Pile Rep:                  ['TD', '6D']
# 3. Other Player Rep:          ['2C', '3C', '5C', '8C', '9C', 'JC', 'QC', '2D', '7D', '9D', 'AD', '4H', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [4D, 8D, QD]
# Final Choice: QD
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', '2D', '9H', '2S', '4S', '5S']
# 2. Pile Rep:                  ['QD', 'TD', '6D']
# 3. Other Player Rep:          ['2C', '3C', '4C', 'TC', 'JC', 'QC', '4D', '7D', '8D', '9D', 'AD', '3H', '4H', 'JH', 'AH', '3S', '6S', '8S', '9S', 'TS', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [2D]
#
# Final Choice: 2D
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', 'TC', '4D', '8D', '3H', '3S', 'QS']
# 2. Pile Rep:                  ['QD', '2D', 'TD', '6D']
# 3. Other Player Rep:          ['2C', '3C', '5C', '8C', '9C', 'JC', 'QC', '7D', '9D', 'AD', '4H', '9H', 'JH', 'AH', '2S', '4S', '5S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3H, 4D, TC, QS, 3S, 8D, 4C]
# Final Choice: QS
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', '9H', '2S', '4S', '5S']
# 2. Pile Rep:                  ['QS']
# 3. Other Player Rep:          ['2C', '3C', '4C', 'TC', 'JC', 'QC', '4D', '7D', '8D', '9D', 'AD', '3H', '4H', 'JH', 'AH', '3S', '6S', '8S', '9S', 'TS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5S, 2S, 4S]
#
# Final Choice: 2S
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['7D', 'AD', 'JH', '6S', '8S', '9S', 'TS']
# 2. Pile Rep:                  ['QS', '2S']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '8C', '9C', 'TC', 'JC', 'QC', '4D', '8D', '9D', '3H', '4H', '9H', 'AH', '3S', '4S', '5S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8S, TS, 9S, 6S]
# Final Choice: TS
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', 'JC', 'QC', '9D', '4H', 'AH']
# 2. Pile Rep:                  ['QS', '2S', 'TS']
# 3. Other Player Rep:          ['4C', '5C', '8C', '9C', 'TC', '4D', '7D', '8D', 'AD', '3H', '9H', 'JH', '3S', '4S', '5S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [9D]
# >> You choose action (integer): 0
#
# Final Choice: 9D
#
#  ************************************** ROUND END (Winner: Player 4)***********************************
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', 'JC', 'QC', '4H', 'AH']
# 2. Pile Rep:                  ['QS', '2S', 'TS', '9D']
# 3. Other Player Rep:          ['4C', '5C', '8C', '9C', 'TC', '4D', '7D', '8D', 'AD', '3H', '9H', 'JH', '3S', '4S', '5S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [2C, 4H, QC, JC, AH, 3C]
# >> You choose action (integer): 0
#
# Final Choice: 2C
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', 'TC', '4D', '8D', '3H', '3S']
# 2. Pile Rep:                  ['2C']
# 3. Other Player Rep:          ['3C', '5C', '8C', '9C', 'JC', 'QC', '7D', 'AD', '4H', '9H', 'JH', 'AH', '4S', '5S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [TC, 4C]
# Final Choice: 4C
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', '9H', '4S', '5S']
# 2. Pile Rep:                  ['4C', '2C']
# 3. Other Player Rep:          ['3C', 'TC', 'JC', 'QC', '4D', '7D', '8D', 'AD', '3H', '4H', 'JH', 'AH', '3S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [9C, 8C, 5C]
#
# Final Choice: 9C
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['7D', 'AD', 'JH', '6S', '8S', '9S']
# 2. Pile Rep:                  ['4C', '9C', '2C']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'TC', 'JC', 'QC', '4D', '8D', '3H', '4H', '9H', 'AH', '3S', '4S', '5S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [AD, 7D]
# Final Choice: 7D
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AD', 'JH', '6S', '8S', '9S']
# 2. Pile Rep:                  ['4C', '9C', '7D', '2C']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'TC', 'JC', 'QC', '4D', '8D', '3H', '4H', '9H', 'AH', '3S', '4S', '5S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [AD, JH, 8S, 9S, 6S]
# Final Choice: AD
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC', 'QC', '4H', 'AH']
# 2. Pile Rep:                  ['AD']
# 3. Other Player Rep:          ['5C', '8C', 'TC', '4D', '8D', '3H', '9H', 'JH', '3S', '4S', '5S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [4H, QC, JC, AH, 3C]
# >> You choose action (integer): 0
#
# Final Choice: 4H
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['TC', '4D', '8D', '3H', '3S']
# 2. Pile Rep:                  ['AD', '4H']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'JC', 'QC', '9H', 'JH', 'AH', '4S', '5S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [4D, 8D]
# Final Choice: 4D
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9H', '4S', '5S']
# 2. Pile Rep:                  ['4D', 'AD', '4H']
# 3. Other Player Rep:          ['3C', 'TC', 'JC', 'QC', '8D', '3H', 'JH', 'AH', '3S', '6S', '8S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5S, 9H, 8C, 5C, 4S]
#
# Final Choice: 4S
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['JH', '6S', '8S', '9S']
# 2. Pile Rep:                  ['4D', '4S', 'AD', '4H']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'TC', 'JC', 'QC', '8D', '3H', '9H', 'AH', '3S', '5S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [JH, 8S, 9S, 6S]
# Final Choice: 9S
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC', 'QC', 'AH']
# 2. Pile Rep:                  ['9S']
# 3. Other Player Rep:          ['5C', '8C', 'TC', '8D', '3H', '9H', 'JH', '3S', '5S', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [QC, JC, AH, 3C]
# >> You choose action (integer): 0
#
# Final Choice: QC
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['TC', '8D', '3H', '3S']
# 2. Pile Rep:                  ['9S', 'QC']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'JC', '9H', 'JH', 'AH', '5S', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3S]
# Final Choice: 3S
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9H', '5S']
# 2. Pile Rep:                  ['3S', '9S', 'QC']
# 3. Other Player Rep:          ['3C', 'TC', 'JC', '8D', '3H', 'JH', 'AH', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5S]
#
# Final Choice: 5S
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['JH', '6S', '8S']
# 2. Pile Rep:                  ['3S', '5S', '9S', 'QC']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'TC', 'JC', '8D', '3H', '9H', 'AH']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [JH, 8S, 6S]
# Final Choice: JH
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC', 'AH']
# 2. Pile Rep:                  ['JH']
# 3. Other Player Rep:          ['5C', '8C', 'TC', '8D', '3H', '9H', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [AH]
# >> You choose action (integer): 0
#
# Final Choice: AH
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['TC', '8D', '3H']
# 2. Pile Rep:                  ['JH', 'AH']
# 3. Other Player Rep:          ['3C', '5C', '8C', 'JC', '9H', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3H]
# Final Choice: 3H
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9H']
# 2. Pile Rep:                  ['3H', 'JH', 'AH']
# 3. Other Player Rep:          ['3C', 'TC', 'JC', '8D', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [9H]
#
# Final Choice: 9H
#
#  ************************************** ROUND END (Winner: Player 4)***********************************
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC']
# 2. Pile Rep:                  ['3H', '9H', 'JH', 'AH']
# 3. Other Player Rep:          ['5C', '8C', 'TC', '8D', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [JC, 3C]
# >> You choose action (integer): 0
#
# Final Choice: JC
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['TC', '8D']
# 2. Pile Rep:                  ['JC']
# 3. Other Player Rep:          ['3C', '5C', '8C', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [TC]
# Final Choice: TC
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C']
# 2. Pile Rep:                  ['TC', 'JC']
# 3. Other Player Rep:          ['3C', '8D', '6S', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8C, 5C]
#
# Final Choice: 8C
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['6S', '8S']
# 2. Pile Rep:                  ['TC', '8C', 'JC']
# 3. Other Player Rep:          ['3C', '5C', '8D']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8S, 6S]
# Final Choice: 6S
#
#  ************************************** ROUND END (Winner: Player 4)***********************************
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C']
# 2. Pile Rep:                  ['TC', '8C', '6S', 'JC']
# 3. Other Player Rep:          ['5C', '8D', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [3C]
# >> You choose action (integer): 0
#
# Final Choice: 3C
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['8D']
# 2. Pile Rep:                  ['3C']
# 3. Other Player Rep:          ['5C', '8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8D]
# Final Choice: 8D
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C']
# 2. Pile Rep:                  ['8D', '3C']
# 3. Other Player Rep:          ['8S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [5C]
#
# Final Choice: 5C
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['8S']
# 2. Pile Rep:                  ['8D', '5C', '3C']
# 3. Other Player Rep:          []
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [13]
# 9. Contract Trump rep:        ['Diamond']
# 10. Contract Highest Bidder:  ['Player 1']
#
# Possible Legal Actions: [8S]
# Final Choice: 8S
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# Payoffs:
# 		Player 1: -16
# 		Player 2: 10
# 		Player 3: -16
# 		Player 4: 10

# %%
if payoffs[1] > payoffs[0]:
    print('Your Team: Won')
else:
    print('Your Team: Lose')
# Out:
# Your Team: Won
