# %%
# ! conda install pytorch torchvision torchaudio cpuonly -c pytorch

# %% [markdown]
# # Import

# %%
import os
import argparse

import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger

# %% [markdown]
# # Training

# %%
#### import torch

import rlcard
from rlcard.agents import RandomAgent
from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger


# Check whether gpu is available
device = get_device()

# Seed numpy, torch, random
set_seed(7)

# Make the environment with seed
env = rlcard.make("bridge", config={'seed': 7})

# Initialize the agent and use random agents as opponents
from rlcard.agents import DQNAgent
agent1 = DQNAgent(num_actions=env.num_actions,
                 state_shape=env.state_shape[0],
                 mlp_layers=[700 , 700],
                 device=device,
                 name='Player 1')

agent2 = RandomAgent(num_actions=env.num_actions, name='Player 2')

agent3 = DQNAgent(num_actions=env.num_actions,
                  state_shape=env.state_shape[0],
                  mlp_layers=[700 , 700],
                  device=device,
                  name='Player 3',
                 )

agent4 = RandomAgent(num_actions=env.num_actions, name='Player 4')


'''
agents = [agent]
for _ in range(env.num_players):
    agents.append(RandomAgent(num_actions=env.num_actions))
'''

agents = [agent1, agent2, agent3, agent4]

env.set_agents(agents)

#for episode in range(10):
for episode in range(2000):
    #print('\n episode:', episode)
    trajectories, payoffs = env.run(is_training=True)
    #break
    # Training
    trajectories = reorganize(trajectories, payoffs)
    for ts in trajectories[0]:
        agent1.feed(ts)
        #agent.feed(ts)
        #rl_loss = agent.train_rl()
        #sl_loss = agent.train_sl()
    for ts in trajectories[2]:
        agent3.feed(ts)
# Out:
# --> Running on the CPU
# /home/naveen/tarneeb_rl/aws/rlcard_harshit_20220714/rlcard/rlcard/agents/dqn_agent.py:216: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   state_batch, action_batch, reward_batch, next_state_batch, legal_actions_batch, done_batch = self.memory.sample()
# INFO - Step 100, rl-loss: 0.47509318590164185
# INFO - Copied model parameters to target network.
# INFO - Step 100, rl-loss: 16.814662933349612
# INFO - Copied model parameters to target network.
# INFO - Step 1100, rl-loss: 6.44963312149047855
# INFO - Copied model parameters to target network.
# INFO - Step 1100, rl-loss: 0.69334924221038826
# INFO - Copied model parameters to target network.
# INFO - Step 2100, rl-loss: 3.4321308135986332
# INFO - Copied model parameters to target network.
# INFO - Step 2100, rl-loss: 7.5966677665710453
# INFO - Copied model parameters to target network.
# INFO - Step 3100, rl-loss: 2.3251588344573975
# INFO - Copied model parameters to target network.
# INFO - Step 3100, rl-loss: 20.079206466674805
# INFO - Copied model parameters to target network.
# INFO - Step 4100, rl-loss: 8.7634105682373057
# INFO - Copied model parameters to target network.
# INFO - Step 4100, rl-loss: 7.1923890113830572
# INFO - Copied model parameters to target network.
# INFO - Step 5100, rl-loss: 2.1143269538879395
# INFO - Copied model parameters to target network.
# INFO - Step 5100, rl-loss: 5.1878643035888673
# INFO - Copied model parameters to target network.
# INFO - Step 6100, rl-loss: 3.6618745326995859
# INFO - Copied model parameters to target network.
# INFO - Step 6100, rl-loss: 14.159137725830078
# INFO - Copied model parameters to target network.
# INFO - Step 7100, rl-loss: 6.9220957756042483
# INFO - Copied model parameters to target network.
# INFO - Step 7100, rl-loss: 7.2278900146484375
# INFO - Copied model parameters to target network.
# INFO - Step 8100, rl-loss: 4.8927593231201176
# INFO - Copied model parameters to target network.
# INFO - Step 8100, rl-loss: 5.3457937240600593
# INFO - Copied model parameters to target network.
# INFO - Step 9100, rl-loss: 8.5115041732788095
# INFO - Copied model parameters to target network.
# INFO - Step 9100, rl-loss: 6.3308486938476562
# INFO - Copied model parameters to target network.
# INFO - Step 10100, rl-loss: 4.4056143760681155
# INFO - Copied model parameters to target network.
# INFO - Step 10100, rl-loss: 3.8368690013885595
# INFO - Copied model parameters to target network.
# INFO - Step 11100, rl-loss: 8.9817552566528324
# INFO - Copied model parameters to target network.
# INFO - Step 11100, rl-loss: 11.646470069885254
# INFO - Copied model parameters to target network.
# INFO - Step 12100, rl-loss: 4.0772299766540532
# INFO - Copied model parameters to target network.
# INFO - Step 12100, rl-loss: 6.3799433708190924
# INFO - Copied model parameters to target network.
# INFO - Step 13100, rl-loss: 5.1876101493835457
# INFO - Copied model parameters to target network.
# INFO - Step 13100, rl-loss: 6.9290161132812548
# INFO - Copied model parameters to target network.
# INFO - Step 14100, rl-loss: 4.1721539497375495
# INFO - Copied model parameters to target network.
# INFO - Step 14100, rl-loss: 6.5928969383239755
# INFO - Copied model parameters to target network.
# INFO - Step 15100, rl-loss: 5.0948348045349124
# INFO - Copied model parameters to target network.
# INFO - Step 15100, rl-loss: 6.3858852386474615
# INFO - Copied model parameters to target network.
# INFO - Step 16100, rl-loss: 4.3446722030639654
# INFO - Copied model parameters to target network.
# INFO - Step 16100, rl-loss: 5.9115242958068855
# INFO - Copied model parameters to target network.
# INFO - Step 17100, rl-loss: 4.3885855674743653
# INFO - Copied model parameters to target network.
# INFO - Step 17100, rl-loss: 8.6448535919189455
# INFO - Copied model parameters to target network.
# INFO - Step 18100, rl-loss: 7.0157327651977544
# INFO - Copied model parameters to target network.
# INFO - Step 18100, rl-loss: 3.4463503360748293
# INFO - Copied model parameters to target network.
# INFO - Step 19100, rl-loss: 4.0842919349670414
# INFO - Copied model parameters to target network.
# INFO - Step 19100, rl-loss: 3.2967829704284674
# INFO - Copied model parameters to target network.
# INFO - Step 20100, rl-loss: 3.0726609230041504
# INFO - Copied model parameters to target network.
# INFO - Step 20100, rl-loss: 7.1694993972778325
# INFO - Copied model parameters to target network.
# INFO - Step 21100, rl-loss: 9.5114469528198244
# INFO - Copied model parameters to target network.
# INFO - Step 21100, rl-loss: 3.2476415634155273
# INFO - Copied model parameters to target network.
# INFO - Step 22100, rl-loss: 3.7127275466918945
# INFO - Copied model parameters to target network.
# INFO - Step 22100, rl-loss: 5.4911384582519532
# INFO - Copied model parameters to target network.
# INFO - Step 23100, rl-loss: 6.6293268203735355
# INFO - Copied model parameters to target network.
# INFO - Step 23100, rl-loss: 5.6696767807006844
# INFO - Copied model parameters to target network.
# INFO - Step 24100, rl-loss: 3.7310092449188232
# INFO - Copied model parameters to target network.
# INFO - Step 24100, rl-loss: 2.9015674591064453
# INFO - Copied model parameters to target network.
# INFO - Step 25100, rl-loss: 4.4130187034606937
# INFO - Copied model parameters to target network.
# INFO - Step 25100, rl-loss: 1.7796912193298344
# INFO - Copied model parameters to target network.
# INFO - Step 26100, rl-loss: 4.2348189353942875
# INFO - Copied model parameters to target network.
# INFO - Step 26100, rl-loss: 1.0826474428176887
# INFO - Copied model parameters to target network.
# INFO - Step 27100, rl-loss: 2.6111669540405273
# INFO - Copied model parameters to target network.
# INFO - Step 28100, rl-loss: 2.2311491966247565
# INFO - Copied model parameters to target network.
# INFO - Step 27100, rl-loss: 4.3228793144226078
# INFO - Copied model parameters to target network.
# INFO - Step 29100, rl-loss: 3.1185879707336426
# INFO - Copied model parameters to target network.
# INFO - Step 28100, rl-loss: 2.5865130424499516
# INFO - Copied model parameters to target network.
# INFO - Step 29355, rl-loss: 2.6025481224060063

# %% [markdown]
# # Saving Trained Model

# %%
save_path_1 = os.path.join('', 'agent1DQN_model1.pth')
save_path_2 = os.path.join('', 'agent2DQN_model1.pth')

# %%
#saving model 
torch.save(agents[0], save_path_1)
torch.save(agents[2], save_path_2)

# %%
print('Saved Location for DQN Agent 1:', save_path_1)
print('Saved Location for DQN Agent 2:', save_path_2)
# Out:
# Saved Location for DQN Agent 1: agent1DQN_model1.pth
# Saved Location for DQN Agent 2: agent2DQN_model1.pth

# %% [markdown]
# # Loading Trained Model

# %%
# #loading models
# ag1 = torch.load('agent1DQN_model1.pth')
# ag3 = torch.load('agent2DQN_model1.pth')

# %% [markdown]
# # Testing

# %% [markdown]
# ## Testing for current/ live trained model

# %%
# # Simulation

# def run_1_simulation():
#     trajectories, payoffs = env.run()
#     if payoffs[0] > payoffs[1]:
#         return 0
#     else:
#         return 1

# %%
# using direct trained agent

# %%
# l1 = [run_1_simulation() for i in range(2000)] 

# sum(l1) / len(l1)
# Out:
# 0.095

# %%
# 1 - sum(l1) / len(l1)
# Out:
# 0.905

# %% [markdown]
# ## Testing simulation for loaded models

# %%
# # Check whether gpu is available
# device = get_device()

# # Seed numpy, torch, random
# set_seed(7)

# # Make the environment with seed
# load_env = rlcard.make("bridge", config={'seed': 7})

# # Initialize the agent and use random agents as opponents
# from rlcard.agents import DQNAgent
# agent1 = torch.load('agent1DQN_model1.pth')
# agent2 = RandomAgent(num_actions=load_env.num_actions, name='Player 2')

# agent3 = torch.load('agent2DQN_model1.pth')
# agent4 = RandomAgent(num_actions=load_env.num_actions, name='Player 4')

# agents = [agent1, agent2, agent3, agent4]

# load_env.set_agents(agents)
# Out:
# --> Running on the CPU

# %%
# # Simulation

# def run_1_simulation():
#     trajectories, payoffs = load_env.run()
#     if payoffs[0] > payoffs[1]:
#         return 0
#     else:
#         return 1

# %%
# l2 = [run_1_simulation() for i in range(2000)] 

# sum(l2) / len(l2)
# Out:
# 0.0985

# %%
# 1 - sum(l2) / len(l2)
# Out:
# 0.9015

# %% [markdown]
# # Game Play

# %% [markdown]
# Play Game for 1 fateiyah

# %%
# agent1.verbose = True
# agent2.verbose = True
# agent3.verbose = True

# %%
# ##### import os
# import argparse

# import torch

# import rlcard
# from rlcard.agents import RandomAgent
# from rlcard.utils import get_device, set_seed, tournament, reorganize, Logger
# from rlcard.agents.human_agent_bridge import HumanAgentBridge

# env2 = rlcard.make("bridge", config={'seed': 7, 'verbose': True})

# agents = [
#           agent1,
#           agent2,
#           agent3,
#           #RandomAgent(num_actions=env2.num_actions, name='Player 1', verbose=True),
#           #RandomAgent(num_actions=env2.num_actions, name='Player 2', verbose=True),
#           #RandomAgent(num_actions=env2.num_actions, name='Player 3', verbose=True),
#           HumanAgentBridge(num_actions=env2.num_actions, name='Player 4', verbose=True)
#          ]


# env2.set_agents(agents)

# _, payoffs = env2.run()
# Out:
# **************************************** Setup ****************************************
# Dealer ID: 1
#
# Player1: [3H, 5D, 4D, TC, JS, QS, 3S, 6H, 8D, 7C, 4C, QD, TH]
#
# Player2: [5S, 9H, KS, KC, 5H, KD, 9C, KH, 8C, 2S, 5C, 2D, 4S]
#
# Player3: [3D, AD, TD, JH, 8S, AC, AS, TS, 9S, 6S, 7H, 7D, QH]
#
# Player4: [2H, JD, 6C, 2C, 8H, 4H, QC, JC, 6D, 9D, AH, 7S, 3C]
#
# Seating Order:
# ```p1```
# p2````p4
# ```p3```
#
# **************************************** Game Start ****************************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '7_Club', '7_Diamond', '7_Hearts', '7_Spade', '8_Club', '8_Diamond', '8_Hearts', '8_Spade', '9_Club', '9_Diamond', '9_Hearts', '9_Spade', '10_Club', '10_Diamond', '10_Hearts', '10_Spade', '11_Club', '11_Diamond', '11_Hearts', '11_Spade', '12_Club', '12_Diamond', '12_Hearts', '12_Spade', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
#
# Final Choice: 9_Club
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_9_Club']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '10_Club', '10_Diamond', '10_Hearts', '10_Spade', '11_Club', '11_Diamond', '11_Hearts', '11_Spade', '12_Club', '12_Diamond', '12_Hearts', '12_Spade', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# Final Choice: 11_Diamond
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_9_Club', 'Player3_11_Diamond']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '12_Club', '12_Diamond', '12_Hearts', '12_Spade', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# >> You choose action (integer):
#  0
# Final Choice: Pass
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_9_Club', 'Player3_11_Diamond', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '12_Club', '12_Diamond', '12_Hearts', '12_Spade', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# Final Choice: Pass
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player1_Pass', 'Player3_11_Diamond', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '12_Club', '12_Diamond', '12_Hearts', '12_Spade', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
#
# Final Choice: 12_Spade
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '2S', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player1_Pass', 'Player2_12_Spade', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass', '13_Club', '13_Diamond', '13_Hearts', '13_Spade']
# Final Choice: Pass
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '2S', '3S', '4S', '5S', '6S', '8S', '9S', 'TS', 'JS', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player1_Pass', 'Player2_12_Spade', 'Player3_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass']
# >> You choose action (integer):
#  0
# Final Choice: Pass
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '2S', '4S', '5S', '6S', '7S', '8S', '9S', 'TS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [0]
# 7. Last 3 Bidding Rep:        ['Player2_12_Spade', 'Player3_Pass', 'Player4_Pass']
# 8. Contract Bid rep:          -
# 9. Contract Trump rep:        -
# 10. Contract Highest Bidder:  -
#
# Possible Legal Actions: ['Pass']
# Final Choice: Pass
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '2S', '4S', '5S', 'KS']
# 2. Pile Rep:                  []
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'TH', 'JH', 'QH', 'AH', '3S', '6S', '7S', '8S', '9S', 'TS', 'JS', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5S, 9H, KS, KC, 5H, KD, 9C, KH, 8C, 2S, 5C, 2D, 4S]
#
# Final Choice: 2S
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'TS', 'AS']
# 2. Pile Rep:                  ['2S']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', '9H', 'TH', 'KH', 'AH', '3S', '4S', '5S', '7S', 'JS', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [8S, AS, TS, 9S, 6S]
# Final Choice: TS
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH', '7S']
# 2. Pile Rep:                  ['2S', 'TS']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', '7H', '9H', 'TH', 'JH', 'QH', 'KH', '3S', '4S', '5S', '6S', '8S', '9S', 'JS', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [7S]
# >> You choose action (integer):
#  0
# Final Choice: 7S
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'JS', 'QS']
# 2. Pile Rep:                  ['2S', 'TS', '7S']
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '4S', '5S', '6S', '8S', '9S', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [JS, QS, 3S]
# Final Choice: JS
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', 'TH', '3S', 'QS']
# 2. Pile Rep:                  ['JS', '2S', 'TS', '7S']
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '2H', '4H', '5H', '7H', '8H', '9H', 'JH', 'QH', 'KH', 'AH', '4S', '5S', '6S', '8S', '9S', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3H, 5D, 4D, TC, QS, 3S, 6H, 8D, 7C, 4C, QD, TH]
# Final Choice: TH
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', '9H', 'KH', '4S', '5S', 'KS']
# 2. Pile Rep:                  ['TH']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '4D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '2H', '3H', '4H', '6H', '7H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '8S', '9S', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [9H, 5H, KH]
#
# Final Choice: 9H
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', '7H', 'JH', 'QH', '6S', '8S', '9S', 'AS']
# 2. Pile Rep:                  ['TH', '9H']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '4D', '5D', '6D', '8D', '9D', 'JD', 'QD', 'KD', '2H', '3H', '4H', '5H', '6H', '8H', 'KH', 'AH', '3S', '4S', '5S', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [JH, 7H, QH]
# Final Choice: 7H
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '2H', '4H', '8H', 'AH']
# 2. Pile Rep:                  ['TH', '9H', '7H']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '4D', '5D', '7D', '8D', 'TD', 'QD', 'KD', 'AD', '3H', '5H', '6H', 'JH', 'QH', 'KH', '3S', '4S', '5S', '6S', '8S', '9S', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [2H, 8H, 4H, AH]
# >> You choose action (integer):
#  0
# Final Choice: 2H
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '4D', '5D', '8D', 'QD', '3H', '6H', '3S', 'QS']
# 2. Pile Rep:                  ['TH', '9H', '7H', '2H']
# 3. Other Player Rep:          ['2C', '3C', '5C', '6C', '8C', '9C', 'JC', 'QC', 'KC', 'AC', '2D', '3D', '6D', '7D', '9D', 'TD', 'JD', 'KD', 'AD', '4H', '5H', '8H', 'JH', 'QH', 'KH', 'AH', '4S', '5S', '6S', '8S', '9S', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3H, 5D, 4D, TC, QS, 3S, 6H, 8D, 7C, 4C, QD]
# Final Choice: 4D
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', 'KD', '5H', 'KH', '4S', '5S', 'KS']
# 2. Pile Rep:                  ['4D']
# 3. Other Player Rep:          ['2C', '3C', '4C', '6C', '7C', 'TC', 'JC', 'QC', 'AC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'JD', 'QD', 'AD', '3H', '4H', '6H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '8S', '9S', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [KD, 2D]
#
# Final Choice: KD
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'AD', 'JH', 'QH', '6S', '8S', '9S', 'AS']
# 2. Pile Rep:                  ['4D', 'KD']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'JD', 'QD', '3H', '4H', '5H', '6H', '8H', 'KH', 'AH', '3S', '4S', '5S', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, AD, TD, 7D]
# Final Choice: AD
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', 'JD', '4H', '8H', 'AH']
# 2. Pile Rep:                  ['4D', 'KD', 'AD']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', 'AC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '3H', '5H', '6H', 'JH', 'QH', 'KH', '3S', '4S', '5S', '6S', '8S', '9S', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [JD, 6D, 9D]
# >> You choose action (integer):
#  0
# Final Choice: JD
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['AC', '3D', '7D', 'TD', 'JH', 'QH', '6S', '8S', '9S', 'AS']
# 2. Pile Rep:                  ['4D', 'KD', 'AD', 'JD']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '3H', '4H', '5H', '6H', '8H', 'KH', 'AH', '3S', '4S', '5S', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, TD, JH, 8S, AC, AS, 9S, 6S, 7D, QH]
# Final Choice: AC
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', '6C', 'JC', 'QC', '6D', '9D', '4H', '8H', 'AH']
# 2. Pile Rep:                  ['AC']
# 3. Other Player Rep:          ['4C', '5C', '7C', '8C', '9C', 'TC', 'KC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '3H', '5H', '6H', 'JH', 'QH', 'KH', '3S', '4S', '5S', '6S', '8S', '9S', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [6C, 2C, QC, JC, 3C]
# >> You choose action (integer):
#  0
# Final Choice: 6C
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', '7C', 'TC', '5D', '8D', 'QD', '3H', '6H', '3S', 'QS']
# 2. Pile Rep:                  ['AC', '6C']
# 3. Other Player Rep:          ['2C', '3C', '5C', '8C', '9C', 'JC', 'QC', 'KC', '2D', '3D', '6D', '7D', '9D', 'TD', '4H', '5H', '8H', 'JH', 'QH', 'KH', 'AH', '4S', '5S', '6S', '8S', '9S', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [TC, 7C, 4C]
# Final Choice: 7C
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '8C', '9C', 'KC', '2D', '5H', 'KH', '4S', '5S', 'KS']
# 2. Pile Rep:                  ['7C', 'AC', '6C']
# 3. Other Player Rep:          ['2C', '3C', '4C', 'TC', 'JC', 'QC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', '3H', '4H', '6H', '8H', 'JH', 'QH', 'AH', '3S', '6S', '8S', '9S', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [KC, 9C, 8C, 5C]
#
# Final Choice: 8C
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', 'TD', 'JH', 'QH', '6S', '8S', '9S', 'AS']
# 2. Pile Rep:                  ['7C', '8C', 'AC', '6C']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '3H', '4H', '5H', '6H', '8H', 'KH', 'AH', '3S', '4S', '5S', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, TD, JH, 8S, AS, 9S, 6S, 7D, QH]
# Final Choice: QH
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', 'JC', 'QC', '6D', '9D', '4H', '8H', 'AH']
# 2. Pile Rep:                  ['QH']
# 3. Other Player Rep:          ['4C', '5C', '9C', 'TC', 'KC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '3H', '5H', '6H', 'JH', 'KH', '3S', '4S', '5S', '6S', '8S', '9S', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [8H, 4H, AH]
# >> You choose action (integer):
#  0
# Final Choice: 8H
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', 'TC', '5D', '8D', 'QD', '3H', '6H', '3S', 'QS']
# 2. Pile Rep:                  ['QH', '8H']
# 3. Other Player Rep:          ['2C', '3C', '5C', '9C', 'JC', 'QC', 'KC', '2D', '3D', '6D', '7D', '9D', 'TD', '4H', '5H', 'JH', 'KH', 'AH', '4S', '5S', '6S', '8S', '9S', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3H, 6H]
# Final Choice: 3H
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '9C', 'KC', '2D', '5H', 'KH', '4S', '5S', 'KS']
# 2. Pile Rep:                  ['3H', 'QH', '8H']
# 3. Other Player Rep:          ['2C', '3C', '4C', 'TC', 'JC', 'QC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', '4H', '6H', 'JH', 'AH', '3S', '6S', '8S', '9S', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5H, KH]
#
# Final Choice: 5H
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', 'TD', 'JH', '6S', '8S', '9S', 'AS']
# 2. Pile Rep:                  ['3H', '5H', 'QH', '8H']
# 3. Other Player Rep:          ['2C', '3C', '4C', '5C', '9C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '4H', '6H', 'KH', 'AH', '3S', '4S', '5S', 'QS', 'KS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, TD, JH, 8S, AS, 9S, 6S, 7D]
# Final Choice: 8S
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['2C', '3C', 'JC', 'QC', '6D', '9D', '4H', 'AH']
# 2. Pile Rep:                  ['8S']
# 3. Other Player Rep:          ['4C', '5C', '9C', 'TC', 'KC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '6H', 'JH', 'KH', '3S', '4S', '5S', '6S', '9S', 'QS', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [2C, 4H, QC, JC, 6D, 9D, AH, 3C]
# >> You choose action (integer):
#  0
# Final Choice: 2C
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', 'TC', '5D', '8D', 'QD', '6H', '3S', 'QS']
# 2. Pile Rep:                  ['8S', '2C']
# 3. Other Player Rep:          ['3C', '5C', '9C', 'JC', 'QC', 'KC', '2D', '3D', '6D', '7D', '9D', 'TD', '4H', 'JH', 'KH', 'AH', '4S', '5S', '6S', '9S', 'KS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [QS, 3S]
# Final Choice: 3S
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '9C', 'KC', '2D', 'KH', '4S', '5S', 'KS']
# 2. Pile Rep:                  ['3S', '8S', '2C']
# 3. Other Player Rep:          ['3C', '4C', 'TC', 'JC', 'QC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', '4H', '6H', 'JH', 'AH', '6S', '9S', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5S, KS, 4S]
#
# Final Choice: KS
#
#  ************************************** ROUND END (Winner: Player 2)***********************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '9C', 'KC', '2D', 'KH', '4S', '5S']
# 2. Pile Rep:                  ['3S', 'KS', '8S', '2C']
# 3. Other Player Rep:          ['3C', '4C', 'TC', 'JC', 'QC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', '4H', '6H', 'JH', 'AH', '6S', '9S', 'QS', 'AS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5S, KC, 9C, KH, 5C, 2D, 4S]
#
# Final Choice: 9C
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', 'TD', 'JH', '6S', '9S', 'AS']
# 2. Pile Rep:                  ['9C']
# 3. Other Player Rep:          ['3C', '4C', '5C', 'TC', 'JC', 'QC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '4H', '6H', 'KH', 'AH', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [AS, 9S, 6S]
# Final Choice: AS
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC', 'QC', '6D', '9D', '4H', 'AH']
# 2. Pile Rep:                  ['9C', 'AS']
# 3. Other Player Rep:          ['4C', '5C', 'TC', 'KC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '6H', 'JH', 'KH', '4S', '5S', '6S', '9S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [QC, JC, 3C]
# >> You choose action (integer):
#  0
# Final Choice: QC
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['4C', 'TC', '5D', '8D', 'QD', '6H', 'QS']
# 2. Pile Rep:                  ['9C', 'AS', 'QC']
# 3. Other Player Rep:          ['3C', '5C', 'JC', 'KC', '2D', '3D', '6D', '7D', '9D', 'TD', '4H', 'JH', 'KH', 'AH', '4S', '5S', '6S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [TC, 4C]
# Final Choice: 4C
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', 'TD', 'JH', '6S', '9S']
# 2. Pile Rep:                  ['4C', '9C', 'AS', 'QC']
# 3. Other Player Rep:          ['3C', '5C', 'TC', 'JC', 'KC', '2D', '5D', '6D', '8D', '9D', 'QD', '4H', '6H', 'KH', 'AH', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, TD, JH, 9S, 6S, 7D]
# Final Choice: JH
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC', '6D', '9D', '4H', 'AH']
# 2. Pile Rep:                  ['JH']
# 3. Other Player Rep:          ['5C', 'TC', 'KC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '6H', 'KH', '4S', '5S', '6S', '9S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [4H, AH]
# >> You choose action (integer):
#  0
# Final Choice: 4H
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['TC', '5D', '8D', 'QD', '6H', 'QS']
# 2. Pile Rep:                  ['JH', '4H']
# 3. Other Player Rep:          ['3C', '5C', 'JC', 'KC', '2D', '3D', '6D', '7D', '9D', 'TD', 'KH', 'AH', '4S', '5S', '6S', '9S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [6H]
# Final Choice: 6H
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', 'KC', '2D', 'KH', '4S', '5S']
# 2. Pile Rep:                  ['6H', 'JH', '4H']
# 3. Other Player Rep:          ['3C', 'TC', 'JC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', 'AH', '6S', '9S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [KH]
#
# Final Choice: KH
#
#  ************************************** ROUND END (Winner: Player 2)***********************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', 'KC', '2D', '4S', '5S']
# 2. Pile Rep:                  ['6H', 'KH', 'JH', '4H']
# 3. Other Player Rep:          ['3C', 'TC', 'JC', '3D', '5D', '6D', '7D', '8D', '9D', 'TD', 'QD', 'AH', '6S', '9S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5S, KC, 5C, 2D, 4S]
#
# Final Choice: KC
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', 'TD', '6S', '9S']
# 2. Pile Rep:                  ['KC']
# 3. Other Player Rep:          ['3C', '5C', 'TC', 'JC', '2D', '5D', '6D', '8D', '9D', 'QD', 'AH', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [9S, 6S]
# Final Choice: 9S
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'JC', '6D', '9D', 'AH']
# 2. Pile Rep:                  ['KC', '9S']
# 3. Other Player Rep:          ['5C', 'TC', '2D', '3D', '5D', '7D', '8D', 'TD', 'QD', '4S', '5S', '6S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [JC, 3C]
# >> You choose action (integer):
#  0
# Final Choice: JC
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['TC', '5D', '8D', 'QD', 'QS']
# 2. Pile Rep:                  ['KC', '9S', 'JC']
# 3. Other Player Rep:          ['3C', '5C', '2D', '3D', '6D', '7D', '9D', 'TD', 'AH', '4S', '5S', '6S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [TC]
# Final Choice: TC
#
#  ************************************** ROUND END (Winner: Player 3)***********************************
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', 'TD', '6S']
# 2. Pile Rep:                  ['TC', 'KC', '9S', 'JC']
# 3. Other Player Rep:          ['3C', '5C', '2D', '5D', '6D', '8D', '9D', 'QD', 'AH', '4S', '5S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, TD, 6S, 7D]
# Final Choice: TD
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', '6D', '9D', 'AH']
# 2. Pile Rep:                  ['TD']
# 3. Other Player Rep:          ['5C', '2D', '3D', '5D', '7D', '8D', 'QD', '4S', '5S', '6S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [6D, 9D]
# >> You choose action (integer):
#  0
# Final Choice: 6D
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['5D', '8D', 'QD', 'QS']
# 2. Pile Rep:                  ['TD', '6D']
# 3. Other Player Rep:          ['3C', '5C', '2D', '3D', '7D', '9D', 'AH', '4S', '5S', '6S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5D, 8D, QD]
# Final Choice: QD
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '2D', '4S', '5S']
# 2. Pile Rep:                  ['QD', 'TD', '6D']
# 3. Other Player Rep:          ['3C', '3D', '5D', '7D', '8D', '9D', 'AH', '6S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [2D]
#
# Final Choice: 2D
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['5D', '8D', 'QS']
# 2. Pile Rep:                  ['QD', '2D', 'TD', '6D']
# 3. Other Player Rep:          ['3C', '5C', '3D', '7D', '9D', 'AH', '4S', '5S', '6S']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5D, QS, 8D]
# Final Choice: 5D
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '4S', '5S']
# 2. Pile Rep:                  ['5D']
# 3. Other Player Rep:          ['3C', '3D', '7D', '8D', '9D', 'AH', '6S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5S, 4S]
#
# Final Choice: 5S
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '7D', '6S']
# 2. Pile Rep:                  ['5D', '5S']
# 3. Other Player Rep:          ['3C', '5C', '8D', '9D', 'AH', '4S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D, 7D]
# Final Choice: 7D
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', '9D', 'AH']
# 2. Pile Rep:                  ['5D', '5S', '7D']
# 3. Other Player Rep:          ['5C', '3D', '8D', '4S', '6S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [9D]
# >> You choose action (integer):
#  0
# Final Choice: 9D
#
#  ************************************** ROUND END (Winner: Player 2)***********************************
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C', '4S']
# 2. Pile Rep:                  ['5D', '5S', '7D', '9D']
# 3. Other Player Rep:          ['3C', '3D', '8D', 'AH', '6S', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5C, 4S]
#
# Final Choice: 4S
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D', '6S']
# 2. Pile Rep:                  ['4S']
# 3. Other Player Rep:          ['3C', '5C', '8D', 'AH', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [6S]
# Final Choice: 6S
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C', 'AH']
# 2. Pile Rep:                  ['4S', '6S']
# 3. Other Player Rep:          ['5C', '3D', '8D', 'QS']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [AH, 3C]
# >> You choose action (integer):
#  0
# Final Choice: AH
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['8D', 'QS']
# 2. Pile Rep:                  ['4S', '6S', 'AH']
# 3. Other Player Rep:          ['3C', '5C', '3D']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [QS]
# Final Choice: QS
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# -------------- STATE / DQN Agent / Player 1 --------------
# 1. My Hand Rep:               ['8D']
# 2. Pile Rep:                  ['QS', '4S', '6S', 'AH']
# 3. Other Player Rep:          ['3C', '5C', '3D']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 1]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [8D]
# Final Choice: 8D
#
# -------------- STATE / Random Agent / Player 2 --------------
# 1. My Hand Rep:               ['5C']
# 2. Pile Rep:                  ['8D']
# 3. Other Player Rep:          ['3C', '3D']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 2]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [5C]
#
# Final Choice: 5C
#
# -------------- STATE / DQN Agent / Player 3 --------------
# 1. My Hand Rep:               ['3D']
# 2. Pile Rep:                  ['8D', '5C']
# 3. Other Player Rep:          ['3C']
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 3]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3D]
# Final Choice: 3D
#
# -------------- STATE / Human Agent / Player 4 --------------
# 1. My Hand Rep:               ['3C']
# 2. Pile Rep:                  ['8D', '5C', '3D']
# 3. Other Player Rep:          []
# 4. Dealer Rep:                [Player 1]
# 5. Current Player:            [Player 4]
# 6. Is PlayCard phase:         [1]
# 7. Last 3 Bidding Rep:        -
# 8. Contract Bid rep:          [12]
# 9. Contract Trump rep:        ['Spade']
# 10. Contract Highest Bidder:  ['Player 2']
#
# Possible Legal Actions: [3C]
# >> You choose action (integer):
#  0
# Final Choice: 3C
#
#  ************************************** ROUND END (Winner: Player 1)***********************************
#
# Winning Trick Count:
# *		Player 1: 10
# *		Player 2: 3
# *		Player 3: 10
# *		Player 4: 3
#
# Payoffs:
# *		Player 1: 10
# *		Player 2: -9
# *		Player 3: 10
# *		Player 4: -9

# %%
# if payoffs[1] > payoffs[0]:
#     print('Your Team: Won')
# else:
#     print('Your Team: Lose')
# Out:
# Your Team: Lose
